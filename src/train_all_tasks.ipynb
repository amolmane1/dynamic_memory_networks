# %%
import dmn
model = dmn.dmn_plus(7)
model.train()
# Out:
# Epoch 0: 0.00% complete, 0 mins, Avg loss: 1.29, Num correct: 4734, Accuracy: 52.60%
#
# Validation avg loss: 0.91, Num correct: 585, Accuracy: 58.50%
# Model saved in file: ../saved-models/task-7.ckpt
#
# 0.0
# Epoch 1: 0.78% complete, 0 mins, Avg loss: 0.84, Num correct: 5965, Accuracy: 66.28%
# 0.264528906935
# Epoch 2: 1.56% complete, 0 mins, Avg loss: 0.74, Num correct: 6607, Accuracy: 73.41%
# 0.29776143923
# Epoch 3: 2.34% complete, 1 mins, Avg loss: 0.66, Num correct: 6897, Accuracy: 76.63%
# 0.335510689988
# Epoch 4: 3.12% complete, 1 mins, Avg loss: 0.62, Num correct: 7039, Accuracy: 78.21%
# 0.346181117342
# Epoch 5: 3.91% complete, 1 mins, Avg loss: 0.59, Num correct: 7096, Accuracy: 78.84%
#
# Validation avg loss: 0.58, Num correct: 801, Accuracy: 80.10%
# Model saved in file: ../saved-models/task-7.ckpt
#
# 0.167397254546
# Epoch 6: 4.69% complete, 1 mins, Avg loss: 0.56, Num correct: 7160, Accuracy: 79.56%
# 0.127640134488
# ...

# %%
model.test()
# Out:
# INFO:tensorflow:Restoring parameters from ../saved-models/task-7.ckpt
# Model restored
# 0 mins, Avg loss: 0.33, Num correct: 929, Accuracy: 92.90%
